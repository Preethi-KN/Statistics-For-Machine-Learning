# %% [markdown]
# # Outliers ,IQR and Boxplot

# %%
import numpy as np
import matplotlib.pyplot as plt

#data with outliers
dataset={11,10,12,14,12,15,14,15,105,12,14,17,19,107,10,13,12,14,108,12,11,14,13,15,10,14,12,10,14,13,15,10}

# %%
dataset.
